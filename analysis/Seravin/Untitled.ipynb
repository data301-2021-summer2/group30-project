# %%
import sys 
sys.path.append('..')

# %%
from scripts import project_functions as pf
df = pf.load_and_process("C:/Users/serav/Documents/UBC/SUMMER 2021/TERM 2/DATA 301/project-group-30/data/raw/police_killings.csv")
df
# Out:
#      age  gender    raceethnicity     month state    cause    armed   pop  \
# 0     16    Male            Black  February    AL  Gunshot       No  3779
# 1     27    Male            White     April    LA  Gunshot       No  2769
# 2     26    Male            White     March    WI  Gunshot       No  4079
# 3     25    Male  Hispanic/Latino     March    CA  Gunshot  Firearm  4343
# 4     29    Male            White     March    OH  Gunshot       No  6809
# ..   ...     ...              ...       ...   ...      ...      ...   ...
# 460   18    Male            Black     April    VA  Gunshot       No  1640
# 461   28    Male  Native American     April    WA    Taser  Firearm  4154
# 462   52    Male            White     March    NC  Gunshot  Firearm  3850
# 463   38  Female            Black  February    CA  Gunshot  Firearm  2544
# 464   48    Male          Unknown   January    CA  Gunshot  Firearm  5177
#
#      share_white  income     urate age_group    pop_group income_bracket  \
# 0           60.5   28375  0.097686   10 - 19  3000 - 4000  28000 - 29000
# 1           53.8   14678  0.065724   20 - 29  2000 - 3000  14000 - 15000
# 2           73.8   25286  0.166293   20 - 29  4000 - 5000  25000 - 26000
# 3            1.2   17194  0.124827   20 - 29  4000 - 5000  17000 - 18000
# 4           92.5   33954  0.063550   20 - 29  6000 - 7000  33000 - 34000
# ..           ...     ...       ...       ...          ...            ...
# 460         40.9   25262  0.152047   10 - 19  1000 - 2000  25000 - 26000
# 461         74.5   18470  0.133650   20 - 29  4000 - 5000  18000 - 19000
# 462         83.2   21175  0.256150   50 - 59  3000 - 4000  21000 - 22000
# 463         21.7   26971  0.069601   30 - 39  2000 - 3000  26000 - 27000
# 464         23.1   33590  0.080912   40 - 49  5000 - 6000  33000 - 34000
#
#      urate_level SW_category
# 0    0.09 - 0.11        Half
# 1    0.06 - 0.08        Half
# 2    0.15 - 0.51        High
# 3    0.12 - 0.15         Low
# 4     0.0 - 0.05   Very High
# ..           ...         ...
# 460  0.12 - 0.15      Medium
# 461  0.12 - 0.15        High
# 462  0.15 - 0.51   Very High
# 463  0.06 - 0.08      Medium
# 464  0.06 - 0.08      Medium
#
# [449 rows x 16 columns]
